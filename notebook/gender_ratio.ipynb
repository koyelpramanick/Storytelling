# %% [markdown]
# ### Overall Male-Female ratio

# %%
import pandas as pd

c_data =  pd.read_csv(".\Characters.csv")

m = c_data[c_data.gender == 'm']['character'].count()
f = c_data[c_data.gender == 'f']['character'].count()

print(m)
print(f)

df = pd.DataFrame([m,f], index=['Male', 'Female'], columns=['x'])
 
# make the plot
df.plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# 1293
# 163
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000161DA5C84E0>],
#       dtype=object)

# %% [markdown]
# This is clear that number of male chacters are more than female characters in Shakespeare's play
